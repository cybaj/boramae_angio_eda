# %%
import os
from matplotlib import pyplot as plt
import cv2

# %%
import matplotlib as mpl

# %%
mpl.rcParams['figure.dpi'] = 300

# %%
import sys

# %%
from label_centerlines import get_centerline

# %%
target_root = os.path.join('./tensorflow-deeplab-v3/dataset/boramae/transformed_dir/')

# %%
target_dir = os.path.join(target_root, '191123_bAC')
jpeg_dir = os.path.join(target_dir, 'jpegs')
png_dir = os.path.join(target_dir, 'pngs')
transformed_dir = os.path.join(target_dir, 'transformed')
target_image_name = 'bAC2938G_rrrrr'

# %%
def drawCenterline(dirname, imgname):
    target_dir = os.path.join(target_root, dirname)
    jpeg_dir = os.path.join(target_dir, 'jpegs')
    png_dir = os.path.join(target_dir, 'pngs')
    transformed_dir = os.path.join(target_dir, 'transformed')
    
    os.system()
    
    target_image_name = imgname
    fig = plt.figure(figsize=(12,6))
    fig.add_subplot(1,2,1)
    jpg = cv2.imread(os.path.join(jpeg_dir, target_image_name+'.jpg'))
    plt.imshow(jpg[:,:,::-1])
    fig.add_subplot(1,2,2)
    png = cv2.imread(os.path.join(png_dir, target_image_name+'.png'))
    plt.imshow(png[:,:,::-1])

# %%
def drawPlot(dirname, imgname):
    target_dir = os.path.join(target_root, dirname)
    jpeg_dir = os.path.join(target_dir, 'jpegs')
    png_dir = os.path.join(target_dir, 'pngs')
    transformed_dir = os.path.join(target_dir, 'transformed')
    target_image_name = imgname
    fig = plt.figure(figsize=(12,6))
    fig.add_subplot(1,2,1)
    jpg = cv2.imread(os.path.join(jpeg_dir, target_image_name+'.jpg'))
    plt.imshow(jpg[:,:,::-1])
    fig.add_subplot(1,2,2)
    png = cv2.imread(os.path.join(png_dir, target_image_name+'.png'))
    plt.imshow(png[:,:,::-1])

# %%
fig = plt.figure(figsize=(12,6))
fig.add_subplot(1,2,1)
jpg = cv2.imread(os.path.join(jpeg_dir, target_image_name+'.jpg'))
plt.imshow(jpg[:,:,::-1])
fig.add_subplot(1,2,2)
png = cv2.imread(os.path.join(png_dir, target_image_name+'.png'))
plt.imshow(png[:,:,::-1])

# %%
drawPlot('200121_yyh', 'yyh1179D_rrrr')

# %%
drawPlot('200121_yyh', 'yyh1200T_rr')

# %%
drawPlot('200121_kmr_ea_sd','kmr957C_rrr')

# %%
drawPlot('200121_jsh_ea','jsh1405R_rrrr')

# %%
drawPlot('191123_bAC', 'bAC2924H_rrrr')

# %%
drawPlot('200121_yms', 'yms1298D_rrr')

# %%
drawPlot('200121_yyh', 'yyh1185S_rrrrr')

# %%
drawPlot('200121_yms', 'yms1282T_r')

# %%
drawPlot('200121_yms', 'yms1274B_rrrrr')

# %%
drawPlot('191123_bAC', 'bAC2923O_rrr')

# %%
drawPlot('191219_bAC_ea', 'bAC2670A')

# %%
drawPlot('191231_koh_av', 'koh838L_rrrrrrr')

# %%
drawPlot('200121_kmr_ea_sd', 'kmr963N_rrrrrr')

# %%
drawPlot('200121_jsh_ea','jsh1374E')
